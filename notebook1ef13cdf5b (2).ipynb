# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/hespress/stories_faits-divers.csv
# /kaggle/input/hespress/comments_marocains-du-monde.csv
# /kaggle/input/hespress/stories_art-et-culture.csv
# /kaggle/input/hespress/comments_regions.csv
# /kaggle/input/hespress/comments_orbites.csv
# /kaggle/input/hespress/stories_regions.csv
# /kaggle/input/hespress/comments_art-et-culture.csv
# /kaggle/input/hespress/stories_sport.csv
# /kaggle/input/hespress/stories_medias.csv
# /kaggle/input/hespress/comments_economie.csv
# /kaggle/input/hespress/comments_medias.csv
# /kaggle/input/hespress/stories_economie.csv
# /kaggle/input/hespress/comments_sport.csv
# /kaggle/input/hespress/comments_politique.csv
# /kaggle/input/hespress/stories_tamazight.csv
# /kaggle/input/hespress/stories_societe.csv
# /kaggle/input/hespress/stories_orbites.csv
# /kaggle/input/hespress/comments_societe.csv
# /kaggle/input/hespress/stories_politique.csv
# /kaggle/input/hespress/stories_marocains-du-monde.csv
# ...

# %%
import matplotlib.pylab as plt

# %%
import seaborn as sns
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
plt.style.use('ggplot')

# %%
#pd.set_option('max_columns',20)

# %%
df1 = pd.read_csv('/kaggle/input/hespress/stories_art-et-culture.csv')

df2 = pd.read_csv('/kaggle/input/hespress/stories_economie.csv')

df3 = pd.read_csv('//kaggle/input/hespress/stories_faits-divers.csv')

df4 = pd.read_csv('/kaggle/input/hespress/stories_marocains-du-monde.csv')

df5 = pd.read_csv('/kaggle/input/hespress/stories_medias.csv')

df6 = pd.read_csv('/kaggle/input/hespress/stories_orbites.csv')

df7 = pd.read_csv('/kaggle/input/hespress/stories_politique.csv')

df8 = pd.read_csv('/kaggle/input/hespress/stories_regions.csv')

df9 = pd.read_csv('/kaggle/input/hespress/stories_societe.csv')

df10 = pd.read_csv('/kaggle/input/hespress/stories_sport.csv')

df11 = pd.read_csv('/kaggle/input/hespress/stories_tamazight.csv')

# %%
dfs = [df1, df2, df3, df4, df5 ,df6, df7, df8, df9, df10, df11]
df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#        Unnamed: 0                                id  \
# 0               0  f06aa998054e11eba66e646e69d991ea
# 1               1  f1cf1b9c054e11ebb718646e69d991ea
# 2               2  f2d282a4054e11eb800f646e69d991ea
# 3               3  f3f46cac054e11eba403646e69d991ea
# 4               4  f50f0476054e11eba31b646e69d991ea
# ...           ...                               ...
# 10995         995  75b0b940055811ebb2ff646e69d991ea
# 10996         996  775c3440055811ebbc60646e69d991ea
# 10997         997  78fea9ba055811eb9e32646e69d991ea
# 10998         998  7a58d38c055811ebb9c9646e69d991ea
# 10999         999  7b769274055811eba13c646e69d991ea
#
#                                                    title  \
# 0         "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1           مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2      فيلم "بدون عنف" لهشام العسري .."كعب الحذاء ووا...
# 3      "تنين ووهان" .. مريم أيت أحمد توقِّع أولى "روا...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'date', 'author', 'story', 'topic'], dtype='object')

# %%
df=df[[
    'id', 'title', 'date', 'author', 'story', 'topic'
]].copy()

# %%
df['story_length'] = df['story'].apply(len)
df['title_length'] = df['title'].apply(len)
#df.to_csv('file.csv', index=False)

# %%
df.columns
# Out:
# Index(['id', 'title', 'date', 'author', 'story', 'topic', 'story_length',
#        'title_length'],
#       dtype='object')

# %%
df=df[[
    'id', 'title', 'date', 'author', 'story', 'topic',
'story_length', 'title_length']].copy()

# %%
df['story_word_count'] = df['story'].apply(lambda x: len(str(x).split()))
df['title_word_count'] = df['title'].apply(lambda x: len(str(x).split()))

# %%
df.dtypes
# Out:
# id                  object
# title               object
# date                object
# author              object
# story               object
# topic               object
# story_length         int64
# title_length         int64
# story_word_count     int64
# title_word_count     int64
# dtype: object

# %%
#pd.datetime(df['date'])
df
# Out:
#                                      id  \
# 0      f06aa998054e11eba66e646e69d991ea
# 1      f1cf1b9c054e11ebb718646e69d991ea
# 2      f2d282a4054e11eb800f646e69d991ea
# 3      f3f46cac054e11eba403646e69d991ea
# 4      f50f0476054e11eba31b646e69d991ea
# ...                                 ...
# 10995  75b0b940055811ebb2ff646e69d991ea
# 10996  775c3440055811ebbc60646e69d991ea
# 10997  78fea9ba055811eb9e32646e69d991ea
# 10998  7a58d38c055811ebb9c9646e69d991ea
# 10999  7b769274055811eba13c646e69d991ea
#
#                                                    title  \
# 0         "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1           مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2      فيلم "بدون عنف" لهشام العسري .."كعب الحذاء ووا...
# 3      "تنين ووهان" .. مريم أيت أحمد توقِّع أولى "روا...
# 4            مسكر يتخلّى عن دعم "الوزارة" بسبب "الجمهور"
# ...                                                  ...
# 10995  نشطاء أمازيغ يدافعون عن "الحقّ" في استقبال إسر...
# ...

# %%
df.isna().sum()
# Out:
# id                  0
# title               0
# date                0
# author              0
# story               0
# topic               0
# story_length        0
# title_length        0
# story_word_count    0
# title_word_count    0
# dtype: int64

# %%
df.loc[df.duplicated(subset=['date'])].head()
# Out:
#                                     id  \
# 1060  679c7ae204e911eb95c7646e69d991ea
# 2189  684d111404f911eba0ad646e69d991ea
# 2531  e319809204fa11ebb041646e69d991ea
# 2535  e87a3dfa04fa11eb8fb4646e69d991ea
# 2553  00ef3fa204fb11eb9a2d646e69d991ea
#
#                                                   title  \
# 1060  الجواهري يدعو إلى دعم الأداء عبر الهاتف لمحارب...
# 2189         التغرير وهتك عرض قاصر يسقطان عشرينيا بفاس‎
# 2531         زوجة أب تنهي حياة طفلين في "القصبة" بمراكش
# 2535       الاعتداء بالسلاح يسقط شخصين بيد الأمن بمراكش
# 2553         الحجارة تطرد "تجار الأضاحي" من الحي الحسني
#
#                                 date                   author  \
# 1060  الثلاثاء 22 شتنبر 2020 - 21:15       هسبريس - يوسف لخضر
# 2189     الأحد 13 شتنبر 2020 - 14:00         هسبريس من الرباط
# 2531       الأحد 02 غشت 2020 - 11:00         هسبريس من الرباط
# 2535       السبت 01 غشت 2020 - 21:15  إبراهيم مغراوي من مراكش
# 2553   الخميس 30 يوليوز 2020 - 12:00  هسبريس من الدار البيضاء
#
# ...

# %%
df.query('date == "الأحد 02 غشت 2020 - 11:00"')
# Out:
#                                     id  \
# 175   b83d437e054f11ebbe6f646e69d991ea
# 2531  e319809204fa11ebb041646e69d991ea
#
#                                                   title  \
# 175   "كتاب جيب لتنمية القراءة" يستنكر الاستثناء مِن...
# 2531         زوجة أب تنهي حياة طفلين في "القصبة" بمراكش
#
#                            date                 author  \
# 175   الأحد 02 غشت 2020 - 11:00  هسبريس - وائل بورشاشن
# 2531  الأحد 02 غشت 2020 - 11:00       هسبريس من الرباط
#
#                                                   story           topic  \
# 175   بعدما اصطدم مشروع إصدار سلسلة من كتب الجيب تأم...  art-et-culture
# 2531  في جريمة بشعة، أقدمت امرأة خمسينية، اليوم الأح...    faits-divers
#
#       story_length  title_length  story_word_count  title_word_count
# 175           3858            64               619                10
# 2531           910            42               142                 8

# %%
df.columns
# Out:
# Index(['id', 'title', 'date', 'author', 'story', 'topic', 'story_length',
#        'title_length', 'story_word_count', 'title_word_count'],
#       dtype='object')

# %%
df=df[[ 'title', 'date', 'author', 'story', 'topic', 'story_length',
       'title_length', 'story_word_count', 'title_word_count']].copy()

# %%
df
# Out:
#                                                    title  \
# 0         "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1           مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2      فيلم "بدون عنف" لهشام العسري .."كعب الحذاء ووا...
# 3      "تنين ووهان" .. مريم أيت أحمد توقِّع أولى "روا...
# 4            مسكر يتخلّى عن دعم "الوزارة" بسبب "الجمهور"
# ...                                                  ...
# 10995  نشطاء أمازيغ يدافعون عن "الحقّ" في استقبال إسر...
# 10996  شاعرة أمازيغية تعتصم بالمطار لرفض استمارتها بـ...
# 10997  وفد إسرائيلي يزور المغرب ويلتقي نشطاء أمازيغ ب...
# 10998  نقاش أمازيغيّ مؤنّث بطنجة يذكّر بكَوْن الحقوق ...
# 10999  أمازيغ يقتحمون مقر البرلمان الليبي مطالبين بـ"...
#
#                                  date                     author  \
# 0       الجمعة 02 أكتوبر 2020 - 23:19           هسبريس من الرباط
# 1       الجمعة 02 أكتوبر 2020 - 07:26           هسبريس من الرباط
# 2       الجمعة 02 أكتوبر 2020 - 04:00            عفيفة الحسينات*
# ...

# %%
df.loc[df.duplicated()]
# Out:
#                                                   title  \
# 1060  الجواهري يدعو إلى دعم الأداء عبر الهاتف لمحارب...
# 7040      إصابات بـ"كوفيد-19" تغلق مدرسة خاصة بالنّاظور
#
#                                 date                       author  \
# 1060  الثلاثاء 22 شتنبر 2020 - 21:15           هسبريس - يوسف لخضر
# 7040  الأربعاء 30 شتنبر 2020 - 01:38  عبد الكريم هرواش من الناظور
#
#                                                   story     topic  \
# 1060  جدّد عبد اللطيف الجواهري، والي بنك المغرب، الد...  economie
# 7040  قرّرت المديرية الإقليمية لوزارة التربية الوطني...   regions
#
#       story_length  title_length  story_word_count  title_word_count
# 1060          1917            62               313                10
# 7040           573            45                83                 6

# %%
pd.set_option('max_colwidth', 100)
df.loc[df.duplicated(subset='story')]
# Out:
#                                                                 title  \
# 1060   الجواهري يدعو إلى دعم الأداء عبر الهاتف لمحاربة ارتفاع "الكاش"
# 5122  لقاح "كورونا" .. هل تنتصر القيم الإنسانية على الهواجس التجارية؟
# 6529            الملك يترأس جلسة عمل حول مواجهة انتشار فيروس "كورونا"
# 7040                    إصابات بـ"كوفيد-19" تغلق مدرسة خاصة بالنّاظور
#
#                                 date                       author  \
# 1060  الثلاثاء 22 شتنبر 2020 - 21:15           هسبريس - يوسف لخضر
# 5122    الأربعاء 26 غشت 2020 - 01:00                إدريس لكريني*
# 6529   الثلاثاء 17 مارس 2020 - 20:09             هسبريس من الرباط
# 7040  الأربعاء 30 شتنبر 2020 - 01:38  عبد الكريم هرواش من الناظور
#
#                                                                                                     story  \
# 1060  جدّد عبد اللطيف الجواهري، والي بنك المغرب، الدعوة إلى اعتماد إجراءات تحفيزية لدعم مشروع الأداء ع...
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [title, date, author, story, topic, story_length, title_length, story_word_count, title_word_count]
# Index: []

# %%
df
# Out:
#                                                                     title  \
# 0                          "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1                            مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2           فيلم "بدون عنف" لهشام العسري .."كعب الحذاء وواقع مؤلم للنساء"
# 3      "تنين ووهان" .. مريم أيت أحمد توقِّع أولى "روايات الجائحة" بالمغرب
# 4                             مسكر يتخلّى عن دعم "الوزارة" بسبب "الجمهور"
# ...                                                                   ...
# 10995      نشطاء أمازيغ يدافعون عن "الحقّ" في استقبال إسرائيليّين بالمغرب
# 10996             شاعرة أمازيغية تعتصم بالمطار لرفض استمارتها بـ"تيفيناغ"
# 10997          وفد إسرائيلي يزور المغرب ويلتقي نشطاء أمازيغ بعدد من المدن
# 10998     نقاش أمازيغيّ مؤنّث بطنجة يذكّر بكَوْن الحقوق تُنتزع ولا تُعطَى
# 10999         أمازيغ يقتحمون مقر البرلمان الليبي مطالبين بـ"دسترة حقوقهم"
#
#                                  date                     author  \
# ...

# %%
df.reset_index(drop=True)
# Out:
#                                                                     title  \
# 0                          "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1                            مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2           فيلم "بدون عنف" لهشام العسري .."كعب الحذاء وواقع مؤلم للنساء"
# 3      "تنين ووهان" .. مريم أيت أحمد توقِّع أولى "روايات الجائحة" بالمغرب
# 4                             مسكر يتخلّى عن دعم "الوزارة" بسبب "الجمهور"
# ...                                                                   ...
# 10993      نشطاء أمازيغ يدافعون عن "الحقّ" في استقبال إسرائيليّين بالمغرب
# 10994             شاعرة أمازيغية تعتصم بالمطار لرفض استمارتها بـ"تيفيناغ"
# 10995          وفد إسرائيلي يزور المغرب ويلتقي نشطاء أمازيغ بعدد من المدن
# 10996     نقاش أمازيغيّ مؤنّث بطنجة يذكّر بكَوْن الحقوق تُنتزع ولا تُعطَى
# 10997         أمازيغ يقتحمون مقر البرلمان الليبي مطالبين بـ"دسترة حقوقهم"
#
#                                  date                     author  \
# ...

# %%
df
# Out:
#                                                                     title  \
# 0                          "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1                            مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2           فيلم "بدون عنف" لهشام العسري .."كعب الحذاء وواقع مؤلم للنساء"
# 3      "تنين ووهان" .. مريم أيت أحمد توقِّع أولى "روايات الجائحة" بالمغرب
# 4                             مسكر يتخلّى عن دعم "الوزارة" بسبب "الجمهور"
# ...                                                                   ...
# 10995      نشطاء أمازيغ يدافعون عن "الحقّ" في استقبال إسرائيليّين بالمغرب
# 10996             شاعرة أمازيغية تعتصم بالمطار لرفض استمارتها بـ"تيفيناغ"
# 10997          وفد إسرائيلي يزور المغرب ويلتقي نشطاء أمازيغ بعدد من المدن
# 10998     نقاش أمازيغيّ مؤنّث بطنجة يذكّر بكَوْن الحقوق تُنتزع ولا تُعطَى
# 10999         أمازيغ يقتحمون مقر البرلمان الليبي مطالبين بـ"دسترة حقوقهم"
#
#                                  date                     author  \
# ...

# %%
df.shape
# Out:
# (10998, 9)

# %%
ax=df['author'].value_counts().head(10).plot(kind='barh',title='top 10 authors')
ax.set_xlabel('number of stories')
ax.set_ylabel('author name')
# Out:
# Text(0, 0.5, 'author name')

# %%
ax=df['story_length'].plot(kind='hist',bins=100,title ='story lenght')
ax.set_xlabel('story lenght')
# Out:
# Text(0.5, 0, 'story lenght')

# %%
ax=df['story_word_count'].plot(kind='kde',title ='number of words in stories')
ax.set_xlabel('number of words')
# Out:
# Text(0.5, 0, 'number of words')

# %%
df.plot(kind='scatter',y='story_word_count',x='title_word_count',title='story words vs title words')
# Out:
# <Axes: title={'center': 'story words vs title words'}, xlabel='title_word_count', ylabel='story_word_count'>

# %%
df.plot(kind='scatter',y='story_length',x='title_length',title='story length vs title length')
# Out:
# <Axes: title={'center': 'story length vs title length'}, xlabel='title_length', ylabel='story_length'>

# %%
#df.plot(kind='barh',x='topic',y='story_word_count',title='topic vs story words')

# %%
df.plot(kind='scatter',y='topic',x='story_word_count',title='topic vs story words')
# Out:
# <Axes: title={'center': 'topic vs story words'}, xlabel='story_word_count', ylabel='topic'>

# %%
#sns.scatterplot(x='story_word_count',y='topic',hue='author',data=df)
df
# Out:
#                                                                     title  \
# 0                          "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1                            مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2           فيلم "بدون عنف" لهشام العسري .."كعب الحذاء وواقع مؤلم للنساء"
# 3      "تنين ووهان" .. مريم أيت أحمد توقِّع أولى "روايات الجائحة" بالمغرب
# 4                             مسكر يتخلّى عن دعم "الوزارة" بسبب "الجمهور"
# ...                                                                   ...
# 10995      نشطاء أمازيغ يدافعون عن "الحقّ" في استقبال إسرائيليّين بالمغرب
# 10996             شاعرة أمازيغية تعتصم بالمطار لرفض استمارتها بـ"تيفيناغ"
# 10997          وفد إسرائيلي يزور المغرب ويلتقي نشطاء أمازيغ بعدد من المدن
# 10998     نقاش أمازيغيّ مؤنّث بطنجة يذكّر بكَوْن الحقوق تُنتزع ولا تُعطَى
# 10999         أمازيغ يقتحمون مقر البرلمان الليبي مطالبين بـ"دسترة حقوقهم"
#
#                                  date                     author  \
# ...

# %%
sns.pairplot(df,vars=['story_length','title_length','story_word_count','title_word_count'],hue='topic')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df,vars=['story_length','title_length'],hue='topic')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#sns.pairplot(df,vars=['story_length','title_length','author'],hue='topic')

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                                     title  \
# 0                          "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1                            مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2           فيلم "بدون عنف" لهشام العسري .."كعب الحذاء وواقع مؤلم للنساء"
# 3      "تنين ووهان" .. مريم أيت أحمد توقِّع أولى "روايات الجائحة" بالمغرب
# 4                             مسكر يتخلّى عن دعم "الوزارة" بسبب "الجمهور"
# ...                                                                   ...
# 10993      نشطاء أمازيغ يدافعون عن "الحقّ" في استقبال إسرائيليّين بالمغرب
# 10994             شاعرة أمازيغية تعتصم بالمطار لرفض استمارتها بـ"تيفيناغ"
# 10995          وفد إسرائيلي يزور المغرب ويلتقي نشطاء أمازيغ بعدد من المدن
# 10996     نقاش أمازيغيّ مؤنّث بطنجة يذكّر بكَوْن الحقوق تُنتزع ولا تُعطَى
# 10997         أمازيغ يقتحمون مقر البرلمان الليبي مطالبين بـ"دسترة حقوقهم"
#
#                                  date                     author  \
# ...

# %%
ax=df['title'].value_counts().head(10).plot(kind='barh',title='top 10 titles')
ax.set_xlabel('number of stories')
ax.set_ylabel('title')
# Out:
# Text(0, 0.5, 'title')

# %%
# import nltk
# from nltk import bigrams
# string_bigrams = Counter(ngrams((str(df['story'])).split(),2))
# df['n-gram'] = string_bigrams.most_common(1)

# %%
df
# Out:
#                                                                     title  \
# 0                          "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1                            مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2           فيلم "بدون عنف" لهشام العسري .."كعب الحذاء وواقع مؤلم للنساء"
# 3      "تنين ووهان" .. مريم أيت أحمد توقِّع أولى "روايات الجائحة" بالمغرب
# 4                             مسكر يتخلّى عن دعم "الوزارة" بسبب "الجمهور"
# ...                                                                   ...
# 10993      نشطاء أمازيغ يدافعون عن "الحقّ" في استقبال إسرائيليّين بالمغرب
# 10994             شاعرة أمازيغية تعتصم بالمطار لرفض استمارتها بـ"تيفيناغ"
# 10995          وفد إسرائيلي يزور المغرب ويلتقي نشطاء أمازيغ بعدد من المدن
# 10996     نقاش أمازيغيّ مؤنّث بطنجة يذكّر بكَوْن الحقوق تُنتزع ولا تُعطَى
# 10997         أمازيغ يقتحمون مقر البرلمان الليبي مطالبين بـ"دسترة حقوقهم"
#
#                                  date                     author  \
# ...

# %%
from collections import Counter
from nltk import ngrams
string = 'وجه "بيت الشعر في المغرب" إلى وزير الثقافة والشباب والرياضة رسالة موسومة بـ"لماذا تحولت أحلام ب'
string_bigrams = Counter(ngrams(string.split(),2))
string_bigrams.most_common(1)
# Out:
# [(('وجه', '"بيت'), 1)]

# %%
df1
# Out:
#      Unnamed: 0                                id  \
# 0             0  f06aa998054e11eba66e646e69d991ea
# 1             1  f1cf1b9c054e11ebb718646e69d991ea
# 2             2  f2d282a4054e11eb800f646e69d991ea
# 3             3  f3f46cac054e11eba403646e69d991ea
# 4             4  f50f0476054e11eba31b646e69d991ea
# ..          ...                               ...
# 995         995  97e7b078055311eb972a646e69d991ea
# 996         996  98f7723e055311ebb811646e69d991ea
# 997         997  9a29bc06055311ebbb05646e69d991ea
# 998         998  9b547968055311ebb870646e69d991ea
# 999         999  9c6b8f50055311eb9c5c646e69d991ea
#
#                                                                   title  \
# 0                        "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1                          مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2         فيلم "بدون عنف" لهشام العسري .."كعب الحذاء وواقع مؤلم للنساء"
# ...

# %%
df1
# Out:
#      Unnamed: 0                                id  \
# 0             0  f06aa998054e11eba66e646e69d991ea
# 1             1  f1cf1b9c054e11ebb718646e69d991ea
# 2             2  f2d282a4054e11eb800f646e69d991ea
# 3             3  f3f46cac054e11eba403646e69d991ea
# 4             4  f50f0476054e11eba31b646e69d991ea
# ..          ...                               ...
# 995         995  97e7b078055311eb972a646e69d991ea
# 996         996  98f7723e055311ebb811646e69d991ea
# 997         997  9a29bc06055311ebbb05646e69d991ea
# 998         998  9b547968055311ebb870646e69d991ea
# 999         999  9c6b8f50055311eb9c5c646e69d991ea
#
#                                                                   title  \
# 0                        "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1                          مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2         فيلم "بدون عنف" لهشام العسري .."كعب الحذاء وواقع مؤلم للنساء"
# ...

# %%
df
# Out:
#                                                                     title  \
# 0                          "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1                            مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2           فيلم "بدون عنف" لهشام العسري .."كعب الحذاء وواقع مؤلم للنساء"
# 3      "تنين ووهان" .. مريم أيت أحمد توقِّع أولى "روايات الجائحة" بالمغرب
# 4                             مسكر يتخلّى عن دعم "الوزارة" بسبب "الجمهور"
# ...                                                                   ...
# 10993      نشطاء أمازيغ يدافعون عن "الحقّ" في استقبال إسرائيليّين بالمغرب
# 10994             شاعرة أمازيغية تعتصم بالمطار لرفض استمارتها بـ"تيفيناغ"
# 10995          وفد إسرائيلي يزور المغرب ويلتقي نشطاء أمازيغ بعدد من المدن
# 10996     نقاش أمازيغيّ مؤنّث بطنجة يذكّر بكَوْن الحقوق تُنتزع ولا تُعطَى
# 10997         أمازيغ يقتحمون مقر البرلمان الليبي مطالبين بـ"دسترة حقوقهم"
#
#                                  date                     author  \
# ...

# %%
Total = df['story'].sum()
print(len(Total))
# Out:
# 25663498

# %%
string_bigrams = Counter(ngrams(Total.split(),1))
string_bigrams.most_common(20)
# Out:
# [(('في',), 128055),
#  (('من',), 103058),
#  (('على',), 60243),
#  (('أن',), 54954),
#  (('إلى',), 53530),
#  (('التي',), 32928),
#  (('عن',), 25071),
#  (('ما',), 19151),
#  (('الذي',), 18975),
#  (('مع',), 17688),
#  (('هذا',), 15253),
#  (('هذه',), 13964),
#  (('لا',), 12216),
#  (('أو',), 11766),
#  (('خلال',), 10800),
#  (('بين',), 10734),
#  (('بعد',), 10146),
#  (('المغرب',), 7711),
#  (('كل',), 7522),
#  (('كان',), 7264)]

# %%
string_bigrams = Counter(ngrams(Total.split(),20))
string_bigrams.most_common(20)
# Out:
# [(('حالة.وتهيب',
#    'وزارة',
#    'الصحة',
#    'بالمواطنات',
#    'والمواطنين',
#    'الالتزام',
#    'بقواعد',
#    'النظافة',
#    'والسلامة',
#    'الصحية،',
#    'والانخراط',
#    'في',
#    'التدابير',
#    'الاحترازية',
#    'التي',
#    'اتخذتها',
#    'السلطات',
#    'المغربية',
#    'بكل',
#    'وطنية'),
#   40),
#  (('الاعتقاد',
#    'عند',
#    'المثقفين',
#    'عموما،',
#    'بل',
#    'حتى',
#    'عند',
#    'بعض',
#    'الباحثين',
#    'المتخصصين،',
#    'بأن',
#    'الحديث',
#    'عن',
#    'المسألة',
#    'الأمازيغية',
#    'إبان',
#    'عهد',
#    'الحماية',
#    'إنما',
#    'يعني'),
#   29),
#  (('عند',
#    'المثقفين',
#    'عموما،',
#    'بل',
#    'حتى',
#    'عند',
#    'بعض',
#    'الباحثين',
#    'المتخصصين،',
#    'بأن',
#    'الحديث',
#    'عن',
#    'المسألة',
#    'الأمازيغية',
#    'إبان',
#    'عهد',
#    'الحماية',
#    'إنما',
#    'يعني',
#    'أساسا'),
#   29),
#  (('المثقفين',
#    'عموما،',
#    'بل',
#    'حتى',
#    'عند',
#    'بعض',
# ...

# %%
Total_df1 = df1['story'].sum()
print(len(Total_df1))
# Out:
# 2675401

# %%
string_bigrams = Counter(ngrams(Total_df1.split(),3))
string_bigrams.most_common(100)
# Out:
# [(('الثقافة', 'والشباب', 'والرياضة'), 71),
#  (('وزارة', 'الثقافة', 'والشباب'), 66),
#  (('مشيرا', 'إلى', 'أن'), 62),
#  (('تصريح', 'لجريدة', 'هسبريس'), 55),
#  (('في', 'تصريح', 'لجريدة'), 54),
#  (('الثقافة', 'والشباب', 'والرياضة،'), 48),
#  (('لجريدة', 'هسبريس', 'الإلكترونية،'), 47),
#  (('المركز', 'السينمائي', 'المغربي'), 46),
#  (('الإشارة', 'إلى', 'أنّ'), 44),
#  (('المهرجان', 'الدولي', 'للفيلم'), 44),
#  (('وزير', 'الثقافة', 'والشباب'), 38),
#  (('لا', 'يمكن', 'أن'), 35),
#  (('في', 'تصريح', 'لهسبريس،'), 34),
#  (('أكاديمية', 'المملكة', 'المغربية'), 33),
#  (('على', 'الرغم', 'من'), 32),
#  (('في', 'العديد', 'من'), 32),
#  (('المكتب', 'المغربي', 'لحقوق'), 32),
#  (('في', 'عدد', 'من'), 29),
#  (('في', 'هذا', 'السياق'), 28),
#  (('المؤسسة', 'الوطنية', 'للمتاحف'), 27),
#  (('الملك', 'محمد', 'السادس'), 26),
#  (('المغربية', 'لمهنيي', 'الفنون'), 26),
#  (('في', 'مجموعة', 'من'), 25),
#  (('السادس', 'للفنّ', 'الحديث'), 25),
#  (('بما', 'في', 'ذلك'), 24),
# ...

# %%
Total_df5 = df5['story'].sum()
print(len(Total_df5))
# Out:
# 3413936

# %%
string_bigrams = Counter(ngrams(Total_df5.split(),4))
string_bigrams.most_common(50)
# Out:
# [(('التي', 'ورد', 'بها', 'أن'), 135),
#  (('بعض', 'الجرائد', 'الورقية', 'الخاصة'), 76),
#  (('مواد', 'بعض', 'الجرائد', 'الورقية'), 54),
#  (('الجرائد', 'الورقية', 'الخاصة', 'بيوم'), 52),
#  (('نستهلها', 'من', '"المساء"،', 'التي'), 49),
#  (('الحكومة،', 'سعد', 'الدين', 'العثماني،'), 48),
#  (('المديرية', 'العامة', 'للأمن', 'الوطني'), 45),
#  (('"المساء"،', 'التي', 'ورد', 'بها'), 43),
#  (('نشرت', '"أخبار', 'اليوم"', 'أن'), 43),
#  (('من', '"الأحداث', 'المغربية"', 'التي'), 43),
#  (('نشرت', '"الأحداث', 'المغربية"', 'أن'), 42),
#  (('رئيس', 'الحكومة،', 'سعد', 'الدين'), 42),
#  (('إلى', 'مصادر', 'الجريدة،', 'فإن'), 42),
#  (('الشركة', 'الوطنية', 'للإذاعة', 'والتلفزة'), 40),
#  (('"الأحداث', 'المغربية"', 'كذلك', 'أن'), 37),
#  (('من', '"المساء"،', 'التي', 'ورد'), 36),
#  (('الفرقة', 'الوطنية', 'للشرطة', 'القضائية'), 36),
#  (('نستهلها', 'من', '"المساء"', 'التي'), 36),
#  (('"المساء"', 'التي', 'ورد', 'بها'), 36),
#  (('"أخبار', 'اليوم"', 'كذلك', 'أن'), 36),
# ...

# %%
df
# Out:
#                                                                     title  \
# 0                          "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1                            مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2           فيلم "بدون عنف" لهشام العسري .."كعب الحذاء وواقع مؤلم للنساء"
# 3      "تنين ووهان" .. مريم أيت أحمد توقِّع أولى "روايات الجائحة" بالمغرب
# 4                             مسكر يتخلّى عن دعم "الوزارة" بسبب "الجمهور"
# ...                                                                   ...
# 10993      نشطاء أمازيغ يدافعون عن "الحقّ" في استقبال إسرائيليّين بالمغرب
# 10994             شاعرة أمازيغية تعتصم بالمطار لرفض استمارتها بـ"تيفيناغ"
# 10995          وفد إسرائيلي يزور المغرب ويلتقي نشطاء أمازيغ بعدد من المدن
# 10996     نقاش أمازيغيّ مؤنّث بطنجة يذكّر بكَوْن الحقوق تُنتزع ولا تُعطَى
# 10997         أمازيغ يقتحمون مقر البرلمان الليبي مطالبين بـ"دسترة حقوقهم"
#
#                                  date                     author  \
# ...

# %%
df1
# Out:
#      Unnamed: 0                                id  \
# 0             0  f06aa998054e11eba66e646e69d991ea
# 1             1  f1cf1b9c054e11ebb718646e69d991ea
# 2             2  f2d282a4054e11eb800f646e69d991ea
# 3             3  f3f46cac054e11eba403646e69d991ea
# 4             4  f50f0476054e11eba31b646e69d991ea
# ..          ...                               ...
# 995         995  97e7b078055311eb972a646e69d991ea
# 996         996  98f7723e055311ebb811646e69d991ea
# 997         997  9a29bc06055311ebbb05646e69d991ea
# 998         998  9b547968055311ebb870646e69d991ea
# 999         999  9c6b8f50055311eb9c5c646e69d991ea
#
#                                                                   title  \
# 0                        "بيت الشعر" يسائل وزير الثقافة عن كوابيس سوداء
# 1                          مهرجان "سينما المؤلّف" يستحضر روح ثريا جبران
# 2         فيلم "بدون عنف" لهشام العسري .."كعب الحذاء وواقع مؤلم للنساء"
# ...

# %%
ax=df['topic'].value_counts().head(11).plot(kind='barh',title='topics ')
ax.set_xlabel('number of stories')
ax.set_ylabel('topic name')
# Out:
# Text(0, 0.5, 'topic name')
